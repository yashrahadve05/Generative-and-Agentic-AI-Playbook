# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import Any

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
llm.invoke('My name is Yash').content
# Out:
# [{'type': 'text',
#   'text': "Hello, Yash! It's nice to meet you. How is your day going? Is there anything I can help you with today?",
#   'extras': {'signature': 'EjQKMgERTTIPeSYJ+RpaxCZZH3QbXCAxDG7q1yQsWn4JZ8PpuwbdF/6qrvhMmUJogME42omD'}}]

# %%
llm.invoke('What is my name').content
# Out:
# [{'type': 'text',
#   'text': 'I don’t know your name. As an AI, I don’t have access to your personal identity, private files, or webcam unless you have explicitly shared that information with me in this specific conversation. \n\nIf you’d like me to remember your name for this chat, feel free to tell me!',
#   'extras': {'signature': 'EjQKMgERTTIP8LojYBKBq8qvOi8CUnbC/NUTUVjByznYv9CR+rVqkZ+hOzrmAWMi88JZzqVJ'}}]

# %%
messages = ['My name is Yash']

# %%
output: Any = llm.invoke(messages).content
output
# Out:
# [{'type': 'text',
#   'text': "Hello, Yash! It's nice to meet you. How are you doing today? Is there anything I can help you with?",
#   'extras': {'signature': 'EjQKMgERTTIPmn+Q7CNkWT3/nVQwLiwAl0sU95m8VspV2Fh8T1XHCT/NT1M0AwTifN+hJYoQ'}}]

# %%
messages.append(output)
messages
# Out:
# ['My name is Yash',
#  [{'type': 'text',
#    'text': "Hello, Yash! It's nice to meet you. How are you doing today? Is there anything I can help you with?",
#    'extras': {'signature': 'EjQKMgERTTIPmn+Q7CNkWT3/nVQwLiwAl0sU95m8VspV2Fh8T1XHCT/NT1M0AwTifN+hJYoQ'}}]]
