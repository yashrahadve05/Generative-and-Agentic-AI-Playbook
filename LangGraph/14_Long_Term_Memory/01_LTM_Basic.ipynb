# %%
from langgraph.store.memory import InMemoryStore

# %%
# creating a store
store = InMemoryStore()

# %%
# creating a name space
namespace = ("user", "u1")

# %% [markdown]
# #### Creating Memories in Long Term Memory

# %%
# Adding memories
store.put(namespace, "1", {"data": "User likes pizza"})
store.put(namespace, "2", {"data": "User prefrers the dark mode"})

# %%
# Another namespace
namespace2 = ("user", "u2")

# Add memories
store.put(namespace2, "1", {"data": "User like meggie"})
store.put(namespace2, "2", {"data": "User prefers the bentogrid layout in the landingpage"})

# %% [markdown]
# #### Retrieving Memories from Long Term Memory

# %%
# Store.get(namespace, key)
store.get(namespace, "1")
# Out:
# Item(namespace=['user', 'u1'], key='1', value={'data': 'User likes pizza'}, created_at='2026-07-12T19:07:43.529526+00:00', updated_at='2026-07-12T19:07:43.529526+00:00')

# %% [markdown]
# #### Retrieving All Memories from Long Term Memory (Searching in a namespace)

# %%
items = store.search(namespace)

for item in items:
    print(item.value)
# Out:
# {'data': 'User likes pizza'}
# {'data': 'User prefrers the dark mode'}

# %% [markdown]
# ### Semantic Search in Long Term Memory

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from dotenv import load_dotenv

load_dotenv()

embedding_model = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2")

# %%
store = InMemoryStore(index={"embed": embedding_model, 'dims': 1523})

# %%
namespace = ("user", "u1")

# %%
store.put(namespace, "1", {"data": "User prefers concise answers over long explanations"})
store.put(namespace, "2", {"data": "User likes examples in Python"})
store.put(namespace, "3", {"data": "User usually works late at night"})
store.put(namespace, "4", {"data": "User prefers dark mode in applications"})
store.put(namespace, "5", {"data": "User is learning machine learning"})
store.put(namespace, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace, "8", {"data": "User is based in India"})
store.put(namespace, "9", {"data": "User likes real-world analogies"})
store.put(namespace, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
items = store.search(namespace, query="What is the user currently learning", limit=1)

for item in items:
    print(item.value)
# Out:
# {'data': 'User is learning machine learning'}

# %%
items2 = store.search(namespace, query="What are the user's preferences", limit=3)

for item in items2:
    print(item.value)
# Out:
# {'data': 'User prefers dark mode in applications'}
# {'data': 'User prefers bullet points over paragraphs'}
# {'data': 'User likes examples in Python'}
